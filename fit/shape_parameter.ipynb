# %%
import ROOT, yaml
import numpy as np
# Out:
# Welcome to JupyROOT 6.30/07

# %%
def fit_signal(signal_mass=1000, remap={'mass_Zprime': 'mass_Zprime', 'weight': 'weight'}, SR='SR1'):
    f = ROOT.TFile(f'input/Run2/mc_signal_Hbb_{signal_mass}.root')
    tree = f.Get('Events')
    mass_Zprime = ROOT.RooRealVar(remap['mass_Zprime'], "mass_Zprime", signal_mass, 650, 4000)
    weight = ROOT.RooRealVar(remap['weight'], "weight", 0, -10, 10)
    mass_Higgs = ROOT.RooRealVar("mass_Higgs", "mass_Higgs", 125, 0, 999)
    tagger_Hbb = ROOT.RooRealVar("tagger_Hbb", "tagger_Hbb", 0, 0, 2)
    tagger_down, tagger_up = {'SR1': 0.7, 'SR2': 0.9}, {'SR1': 0.9, 'SR2': 2}
    SR_cut = f"(mass_Higgs>110) & (mass_Higgs<145) & (tagger_Hbb>{tagger_down[SR]}) & (tagger_Hbb<{tagger_up[SR]})"
    mc = ROOT.RooDataSet("signal_Hbb", "signal_Hbb", tree, ROOT.RooArgSet(mass_Zprime, weight, mass_Higgs, tagger_Hbb), SR_cut, remap['weight'])
    
    x0 = ROOT.RooRealVar("x0", "x0", signal_mass, signal_mass - 200, signal_mass + 200)
    sigmaL = ROOT.RooRealVar("sigmaL", "sigmaL", 50, 1e-8, 200)
    sigmaR = ROOT.RooRealVar("sigmaR", "sigmaR", 50, 1e-8, 200)
    alphaL = ROOT.RooRealVar("alphaL", "alphaL", 2, 1e-8, 6)
    alphaR = ROOT.RooRealVar("alphaR", "alphaR", 2, 1e-8, 6)
    nL = ROOT.RooRealVar("nL", "nL", 1, 1e-8, 50)
    nR = ROOT.RooRealVar("nR", "nR", 1, 1e-8, 50)

    model_signal = ROOT.RooCrystalBall("model_signal", "model_signal", mass_Zprime, x0, sigmaL, sigmaR, alphaL, nL, alphaR, nR)
    model_signal.fitTo(mc, ROOT.RooFit.SumW2Error(True))

    """
    print("x0:", x0.getVal())
    print("sigmaL:", sigmaL.getVal())
    print("sigmaR:", sigmaR.getVal())
    print("alphaL:", alphaL.getVal())
    print("alphaR:", alphaR.getVal())
    print("nL:", nL.getVal())
    print("nR:", nR.getVal())
    """
    return x0.getVal(), sigmaL.getVal(), sigmaR.getVal()

# %%
parameters = {}
uncertainties = {}
for SR in ['SR1', 'SR2']:
    uncertainties[SR] = {}
    for m in [700, 800, 900, 1000, 1200, 1400, 1600, 1800, 2000, 2200, 2400, 2600, 3000, 3500]:
        parameters['nominal'] = fit_signal(signal_mass=m, SR=SR)
        parameters['JES_up'] = fit_signal(signal_mass=m, remap={'mass_Zprime': 'mass_Zprime_JES_up', 'weight': 'weight'}, SR=SR)
        parameters['JES_down'] = fit_signal(signal_mass=m, remap={'mass_Zprime': 'mass_Zprime_JES_down', 'weight': 'weight'}, SR=SR)
        parameters['JER_up'] = fit_signal(signal_mass=m, remap={'mass_Zprime': 'mass_Zprime_JER_up', 'weight': 'weight'}, SR=SR)
        parameters['JER_down'] = fit_signal(signal_mass=m, remap={'mass_Zprime': 'mass_Zprime_JER_down', 'weight': 'weight'}, SR=SR)
        parameters['PU_up'] = fit_signal(signal_mass=m, remap={'mass_Zprime': 'mass_Zprime', 'weight': 'weight_PU_up'}, SR=SR)
        parameters['PU_down'] = fit_signal(signal_mass=m, remap={'mass_Zprime': 'mass_Zprime', 'weight': 'weight_PU_down'}, SR=SR)

        uncertainties[SR][m] = {
            'x0': {
                k: (parameters[f'{k}_up'][0] - parameters[f'{k}_down'][0])/parameters['nominal'][0]/2
                for k in ['JES', 'JER', 'PU']
            },
            'sigmaL': {
                k: (parameters[f'{k}_up'][1] - parameters[f'{k}_down'][1])/parameters['nominal'][1]/2
                for k in ['JES', 'JER', 'PU']
            },
            'sigmaR': {
                k: (parameters[f'{k}_up'][2] - parameters[f'{k}_down'][2])/parameters['nominal'][2]/2
                for k in ['JES', 'JER', 'PU']
            }
        }
# Out:
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(mass_Zprime) TTree Float_t branch mass_Zprime will be converted to double precision.
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(mass_Higgs) TTree Float_t branch mass_Higgs will be converted to double precision.
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(tagger_Hbb) TTree Float_t branch tagger_Hbb will be converted to double precision.
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #23 because mass_Zprime cannot accommodate the value 638.779
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #24 because mass_Zprime cannot accommodate the value 646.491
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #39 because mass_Zprime cannot accommodate the value 636.215
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #44 because mass_Zprime cannot accommodate the value 639.401
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping ...
# [#0] WARNING:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Ignored 13503 out-of-range events
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 335.133752905504252
# Edm   = 0.000112233632959809912
# Nfcn  = 226
# alphaL	  = 2.88588	 +/-  4.25312	(limited)
# alphaR	  = 3.03244	 +/-  0.566608	(limited)
# nL	  = 1	 +/-  11.0327	(limited)
# nR	  = 1.77597	 +/-  0.485577	(limited)
# sigmaL	  = 36.5746	 +/-  14.295	(limited)
# sigmaR	  = 27.8729	 +/-  6.63368	(limited)
# x0	  = 706.993	 +/-  11.1161	(limited)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JES_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JES_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JER_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JER_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'weight_PU_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'weight_PU_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(mass_Zprime) TTree Float_t branch mass_Zprime will be converted to double precision.
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(mass_Higgs) TTree Float_t branch mass_Higgs will be converted to double precision.
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(tagger_Hbb) TTree Float_t branch tagger_Hbb will be converted to double precision.
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #132 because mass_Zprime cannot accommodate the value 625.686
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #346 because mass_Zprime cannot accommodate the value 648.783
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #492 because mass_Zprime cannot accommodate the value 591.111
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #537 because mass_Zprime cannot accommodate the value 649.407
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping ...
# [#0] WARNING:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Ignored 398 out-of-range events
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 481.427217375520627
# Edm   = 0.000508394257421045971
# Nfcn  = 473
# alphaL	  = 1.66092	 +/-  0.971768	(limited)
# alphaR	  = 2.64617	 +/-  1.4566	(limited)
# nL	  = 33.1327	 +/-  41.5449	(limited)
# nR	  = 2.50745	 +/-  4.55591	(limited)
# sigmaL	  = 43.1275	 +/-  10.9048	(limited)
# sigmaR	  = 27.5443	 +/-  7.08638	(limited)
# x0	  = 810.154	 +/-  11.2153	(limited)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JES_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JES_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JER_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JER_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'weight_PU_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'weight_PU_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(mass_Zprime) TTree Float_t branch mass_Zprime will be converted to double precision.
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(mass_Higgs) TTree Float_t branch mass_Higgs will be converted to double precision.
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(tagger_Hbb) TTree Float_t branch tagger_Hbb will be converted to double precision.
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #183 because mass_Zprime cannot accommodate the value 514.953
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #1018 because mass_Zprime cannot accommodate the value 582.54
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #3137 because mass_Zprime cannot accommodate the value 439.72
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #3662 because mass_Zprime cannot accommodate the value 572.862
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping ...
# [#0] WARNING:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Ignored 69 out-of-range events
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 483.780395475229625
# Edm   = 0.000758133742161001085
# Nfcn  = 390
# alphaL	  = 1.31788	 +/-  0.72128	(limited)
# alphaR	  = 2.48312	 +/-  1.58743	(limited)
# nL	  = 48.6702	 +/-  49.3139	(limited)
# nR	  = 3.28116	 +/-  7.14971	(limited)
# sigmaL	  = 43.3702	 +/-  16.6795	(limited)
# sigmaR	  = 30.5777	 +/-  8.51133	(limited)
# x0	  = 908.577	 +/-  13.6218	(limited)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JES_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JES_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JER_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JER_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'weight_PU_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'weight_PU_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(mass_Zprime) TTree Float_t branch mass_Zprime will be converted to double precision.
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(mass_Higgs) TTree Float_t branch mass_Higgs will be converted to double precision.
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(tagger_Hbb) TTree Float_t branch tagger_Hbb will be converted to double precision.
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #2317 because mass_Zprime cannot accommodate the value 533.385
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #2786 because mass_Zprime cannot accommodate the value 488.077
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #5925 because mass_Zprime cannot accommodate the value 578.267
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #6855 because mass_Zprime cannot accommodate the value 619.46
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping ...
# [#0] WARNING:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Ignored 38 out-of-range events
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 456.083445530126141
# Edm   = 0.000174916739161463811
# Nfcn  = 451
# alphaL	  = 1.32014	 +/-  0.656344	(limited)
# alphaR	  = 2.66117	 +/-  1.2631	(limited)
# nL	  = 49.5594	 +/-  25.1828	(limited)
# nR	  = 2.2654	 +/-  3.6401	(limited)
# sigmaL	  = 47.9701	 +/-  16.9754	(limited)
# sigmaR	  = 32.1329	 +/-  8.3992	(limited)
# x0	  = 1009.2	 +/-  14.0448	(limited)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JES_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JES_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JER_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JER_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'weight_PU_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'weight_PU_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(mass_Zprime) TTree Float_t branch mass_Zprime will be converted to double precision.
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(mass_Higgs) TTree Float_t branch mass_Higgs will be converted to double precision.
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(tagger_Hbb) TTree Float_t branch tagger_Hbb will be converted to double precision.
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #6997 because mass_Zprime cannot accommodate the value 628.627
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #9618 because mass_Zprime cannot accommodate the value 532.948
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #14004 because mass_Zprime cannot accommodate the value 624.668
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #14474 because mass_Zprime cannot accommodate the value 627.068
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping ...
# [#0] WARNING:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Ignored 20 out-of-range events
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 354.247905092072187
# Edm   = 4.35937780796363935e-05
# Nfcn  = 546
# alphaL	  = 1.34519	 +/-  0.9538	(limited)
# alphaR	  = 2.47508	 +/-  1.2619	(limited)
# nL	  = 49.9135	 +/-  35.0138	(limited)
# nR	  = 2.52606	 +/-  4.26238	(limited)
# sigmaL	  = 58.0926	 +/-  28.666	(limited)
# sigmaR	  = 37.331	 +/-  12.9246	(limited)
# x0	  = 1210.47	 +/-  22.2525	(limited)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JES_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JES_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JER_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JER_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'weight_PU_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'weight_PU_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(mass_Zprime) TTree Float_t branch mass_Zprime will be converted to double precision.
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(mass_Higgs) TTree Float_t branch mass_Higgs will be converted to double precision.
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(tagger_Hbb) TTree Float_t branch tagger_Hbb will be converted to double precision.
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #686 because mass_Zprime cannot accommodate the value 517.855
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #3473 because mass_Zprime cannot accommodate the value 504.906
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #3775 because mass_Zprime cannot accommodate the value 528.773
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #6348 because mass_Zprime cannot accommodate the value 604.442
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping ...
# [#0] WARNING:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Ignored 36 out-of-range events
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 245.8248604937518
# Edm   = 0.000248255063811468764
# Nfcn  = 460
# alphaL	  = 0.970633	 +/-  1.23818	(limited)
# alphaR	  = 2.21131	 +/-  1.64797	(limited)
# nL	  = 27.6191	 +/-  38.261	(limited)
# nR	  = 3.40523	 +/-  7.47884	(limited)
# sigmaL	  = 54.2471	 +/-  51.0058	(limited)
# sigmaR	  = 40.3036	 +/-  18.8782	(limited)
# x0	  = 1408.95	 +/-  30.4323	(limited)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JES_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JES_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JER_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JER_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'weight_PU_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'weight_PU_down' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#0] ERROR:Fitting -- RooAbsPdf::fitTo(model_signal) ERROR: Cannot apply sum-of-weights correction to covariance matrix: correction matrix calculated with weight-squared is singular
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(mass_Zprime) TTree Float_t branch mass_Zprime will be converted to double precision.
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(mass_Higgs) TTree Float_t branch mass_Higgs will be converted to double precision.
# [#1] INFO:DataHandling -- RooAbsReal::attachToTree(tagger_Hbb) TTree Float_t branch tagger_Hbb will be converted to double precision.
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #6522 because mass_Zprime cannot accommodate the value 626.608
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #10901 because mass_Zprime cannot accommodate the value 526.575
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #13283 because mass_Zprime cannot accommodate the value 525.291
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping event #13776 because mass_Zprime cannot accommodate the value 584.771
# [#1] INFO:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Skipping ...
# [#0] WARNING:DataHandling -- RooTreeDataStore::loadValues(signal_Hbb) Ignored 23 out-of-range events
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Valid minimum - status = 0
# FVAL  = 171.289729586676998
# Edm   = 0.000643951888004608568
# Nfcn  = 458
# alphaL	  = 0.991669	 +/-  1.08165	(limited)
# alphaR	  = 2.48235	 +/-  1.88101	(limited)
# nL	  = 44.3491	 +/-  28.9029	(limited)
# nR	  = 2.57507	 +/-  6.62854	(limited)
# sigmaL	  = 61.5709	 +/-  55.8532	(limited)
# sigmaR	  = 48.0255	 +/-  22.1683	(limited)
# x0	  = 1605.35	 +/-  37.6437	(limited)
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: deactivating const optimization
# [#0] ERROR:InputArguments -- Didn't find a branch in Tree 'Events' to read variable 'mass_Zprime_JES_up' from.
# 	Note: Name the RooFit variable the same as the branch.
# [#0] ERROR:InputArguments -- Cannot import data from TTree 'Events' because some branches are missing !
# [#1] INFO:Minimization -- RooAbsMinimizerFcn::setOptimizeConst: activating const optimization
# Minuit2Minimizer: Minimize with max-calls 3500 convergence for edm < 1 strategy 1
# Minuit2Minimizer : Invalid Minimum - status = 2
# FVAL  = 0
# Edm   = 0
# Nfcn  = 36
# [#1] INFO:Fitting -- RooAbsPdf::fitTo(model_signal) Calculating sum-of-weights-squared correction matrix for covariance matrix
# ...
#  [              0              2              0              0              0              0              0]
#  [              0              0              2              0              0              0              0]
#  [              0              0              0              2              0              0              0]
#  [              0              0              0              0              2              0              0]
#  [              0              0              0              0              0              2              0]
#  [              0              0              0              0              0              0              2]]]
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 0
#   Edm           : 0
#   Internal parameters:	[    -0.3398369118    -0.3398369118     -1.287002219     -1.287002219    -0.5235987757    -0.5235987757                0]
#   Internal gradient  :	[                0                0                0                0                0                0                0]
#   Internal covariance matrix:
# [[              2              0              0              0              0              0              0]
#  [              0              2              0              0              0              0              0]
#  [              0              0              2              0              0              0              0]
#  [              0              0              0              2              0              0              0]
#  [              0              0              0              0              2              0              0]
#  [              0              0              0              0              0              2              0]
#  [              0              0              0              0              0              0              2]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 3500
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =                 0 Edm =                 0 NCalls =     29
# Warning in <Minuit2>: MnHesse 2nd derivative zero for parameter alphaL ; MnHesse fails and will return diagonal matrix
# Info in <Minuit2>: VariableMetricBuilder After Hessian
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =                 0 Edm =                 0 NCalls =     36
# Warning in <Minuit2>: VariableMetricBuilder Invalid Hessian - exit the minimization
# Warning in <Minuit2>: Minuit2Minimizer::Minimize Minimization did NOT converge, Hesse is not valid
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 3500
# Warning in <Minuit2>: MnHesse 2nd derivative zero for parameter alphaL ; MnHesse fails and will return diagonal matrix
# Warning in <Minuit2>: Minuit2Minimizer::Hesse Hesse failed - matrix is full but not positive defined
# Warning in <Minuit2>: Minuit2Minimizer::Hesse 3
# Warning in <ROOT::Math::Fitter::CalculateHessErrors>: Error when calculating Hessian
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 3500
# Warning in <Minuit2>: MnHesse 2nd derivative zero for parameter alphaL ; MnHesse fails and will return diagonal matrix
# Warning in <Minuit2>: Minuit2Minimizer::Hesse Hesse failed - matrix is full but not positive defined
# Warning in <Minuit2>: Minuit2Minimizer::Hesse 3
# Warning in <ROOT::Math::Fitter::CalculateHessErrors>: Error when calculating Hessian
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =                 0 Edm =                 0 NCalls =     29
# Info in <Minuit2>: NegativeG2LineSearch Doing a NegativeG2LineSearch since one of the G2 component is negative
# Info in <Minuit2>: MnSeedGenerator Negative G2 found - new state:
#   Minimum value : 0
#   Edm           : 0
#   Internal parameters:	[    -0.3398369118    -0.3398369118     -1.287002219     -1.287002219    -0.5235987757    -0.5235987757                0]
#   Internal gradient  :	[                0                0                0                0                0                0                0]
#   Internal covariance matrix:
# [[              2              0              0              0              0              0              0]
#  [              0              2              0              0              0              0              0]
#  [              0              0              2              0              0              0              0]
#  [              0              0              0              2              0              0              0]
#  [              0              0              0              0              2              0              0]
#  [              0              0              0              0              0              2              0]
#  [              0              0              0              0              0              0              2]]]
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 0
#   Edm           : 0
#   Internal parameters:	[    -0.3398369118    -0.3398369118     -1.287002219     -1.287002219    -0.5235987757    -0.5235987757                0]
#   Internal gradient  :	[                0                0                0                0                0                0                0]
#   Internal covariance matrix:
# [[              2              0              0              0              0              0              0]
#  [              0              2              0              0              0              0              0]
#  [              0              0              2              0              0              0              0]
#  [              0              0              0              2              0              0              0]
#  [              0              0              0              0              2              0              0]
#  [              0              0              0              0              0              2              0]
#  [              0              0              0              0              0              0              2]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 3500
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =                 0 Edm =                 0 NCalls =     29
# Warning in <Minuit2>: MnHesse 2nd derivative zero for parameter alphaL ; MnHesse fails and will return diagonal matrix
# Info in <Minuit2>: VariableMetricBuilder After Hessian
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =                 0 Edm =                 0 NCalls =     36
# Warning in <Minuit2>: VariableMetricBuilder Invalid Hessian - exit the minimization
# Warning in <Minuit2>: Minuit2Minimizer::Minimize Minimization did NOT converge, Hesse is not valid
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 3500
# Warning in <Minuit2>: MnHesse 2nd derivative zero for parameter alphaL ; MnHesse fails and will return diagonal matrix
# Warning in <Minuit2>: Minuit2Minimizer::Hesse Hesse failed - matrix is full but not positive defined
# Warning in <Minuit2>: Minuit2Minimizer::Hesse 3
# Warning in <ROOT::Math::Fitter::CalculateHessErrors>: Error when calculating Hessian
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 3500
# Warning in <Minuit2>: MnHesse 2nd derivative zero for parameter alphaL ; MnHesse fails and will return diagonal matrix
# Warning in <Minuit2>: Minuit2Minimizer::Hesse Hesse failed - matrix is full but not positive defined
# Warning in <Minuit2>: Minuit2Minimizer::Hesse 3
# Warning in <ROOT::Math::Fitter::CalculateHessErrors>: Error when calculating Hessian
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =                 0 Edm =                 0 NCalls =     29
# Info in <Minuit2>: NegativeG2LineSearch Doing a NegativeG2LineSearch since one of the G2 component is negative
# Info in <Minuit2>: MnSeedGenerator Negative G2 found - new state:
#   Minimum value : 0
#   Edm           : 0
#   Internal parameters:	[    -0.3398369118    -0.3398369118     -1.287002219     -1.287002219    -0.5235987757    -0.5235987757                0]
#   Internal gradient  :	[                0                0                0                0                0                0                0]
#   Internal covariance matrix:
# [[              2              0              0              0              0              0              0]
#  [              0              2              0              0              0              0              0]
#  [              0              0              2              0              0              0              0]
#  [              0              0              0              2              0              0              0]
#  [              0              0              0              0              2              0              0]
#  [              0              0              0              0              0              2              0]
#  [              0              0              0              0              0              0              2]]]
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 0
#   Edm           : 0
#   Internal parameters:	[    -0.3398369118    -0.3398369118     -1.287002219     -1.287002219    -0.5235987757    -0.5235987757                0]
#   Internal gradient  :	[                0                0                0                0                0                0                0]
#   Internal covariance matrix:
# [[              2              0              0              0              0              0              0]
#  [              0              2              0              0              0              0              0]
#  [              0              0              2              0              0              0              0]
#  [              0              0              0              2              0              0              0]
#  [              0              0              0              0              2              0              0]
#  [              0              0              0              0              0              2              0]
#  [              0              0              0              0              0              0              2]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 3500
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =                 0 Edm =                 0 NCalls =     29
# Warning in <Minuit2>: MnHesse 2nd derivative zero for parameter alphaL ; MnHesse fails and will return diagonal matrix
# Info in <Minuit2>: VariableMetricBuilder After Hessian
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =                 0 Edm =                 0 NCalls =     36
# Warning in <Minuit2>: VariableMetricBuilder Invalid Hessian - exit the minimization
# Warning in <Minuit2>: Minuit2Minimizer::Minimize Minimization did NOT converge, Hesse is not valid
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 3500
# Warning in <Minuit2>: MnHesse 2nd derivative zero for parameter alphaL ; MnHesse fails and will return diagonal matrix
# Warning in <Minuit2>: Minuit2Minimizer::Hesse Hesse failed - matrix is full but not positive defined
# Warning in <Minuit2>: Minuit2Minimizer::Hesse 3
# Warning in <ROOT::Math::Fitter::CalculateHessErrors>: Error when calculating Hessian
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 3500
# Warning in <Minuit2>: MnHesse 2nd derivative zero for parameter alphaL ; MnHesse fails and will return diagonal matrix
# Warning in <Minuit2>: Minuit2Minimizer::Hesse Hesse failed - matrix is full but not positive defined
# Warning in <Minuit2>: Minuit2Minimizer::Hesse 3
# Warning in <ROOT::Math::Fitter::CalculateHessErrors>: Error when calculating Hessian
# Info in <Minuit2>: MnSeedGenerator Computing seed using NumericalGradient calculator
# Info in <Minuit2>: MnSeedGenerator Initial state: FCN =                 0 Edm =                 0 NCalls =     29
# Info in <Minuit2>: NegativeG2LineSearch Doing a NegativeG2LineSearch since one of the G2 component is negative
# Info in <Minuit2>: MnSeedGenerator Negative G2 found - new state:
#   Minimum value : 0
#   Edm           : 0
#   Internal parameters:	[    -0.3398369118    -0.3398369118     -1.287002219     -1.287002219    -0.5235987757    -0.5235987757                0]
#   Internal gradient  :	[                0                0                0                0                0                0                0]
#   Internal covariance matrix:
# [[              2              0              0              0              0              0              0]
#  [              0              2              0              0              0              0              0]
#  [              0              0              2              0              0              0              0]
#  [              0              0              0              2              0              0              0]
#  [              0              0              0              0              2              0              0]
#  [              0              0              0              0              0              2              0]
#  [              0              0              0              0              0              0              2]]]
# Info in <Minuit2>: MnSeedGenerator Initial state
#   Minimum value : 0
#   Edm           : 0
#   Internal parameters:	[    -0.3398369118    -0.3398369118     -1.287002219     -1.287002219    -0.5235987757    -0.5235987757                0]
#   Internal gradient  :	[                0                0                0                0                0                0                0]
#   Internal covariance matrix:
# [[              2              0              0              0              0              0              0]
#  [              0              2              0              0              0              0              0]
#  [              0              0              2              0              0              0              0]
#  [              0              0              0              2              0              0              0]
#  [              0              0              0              0              2              0              0]
#  [              0              0              0              0              0              2              0]
#  [              0              0              0              0              0              0              2]]]
# Info in <Minuit2>: VariableMetricBuilder Start iterating until Edm is < 0.001 with call limit = 3500
# Info in <Minuit2>: VariableMetricBuilder    0 - FCN =                 0 Edm =                 0 NCalls =     29
# Warning in <Minuit2>: MnHesse 2nd derivative zero for parameter alphaL ; MnHesse fails and will return diagonal matrix
# Info in <Minuit2>: VariableMetricBuilder After Hessian
# Info in <Minuit2>: VariableMetricBuilder    1 - FCN =                 0 Edm =                 0 NCalls =     36
# Warning in <Minuit2>: VariableMetricBuilder Invalid Hessian - exit the minimization
# Warning in <Minuit2>: Minuit2Minimizer::Minimize Minimization did NOT converge, Hesse is not valid
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 3500
# Warning in <Minuit2>: MnHesse 2nd derivative zero for parameter alphaL ; MnHesse fails and will return diagonal matrix
# Warning in <Minuit2>: Minuit2Minimizer::Hesse Hesse failed - matrix is full but not positive defined
# Warning in <Minuit2>: Minuit2Minimizer::Hesse 3
# Warning in <ROOT::Math::Fitter::CalculateHessErrors>: Error when calculating Hessian
# Info in <Minuit2>: Minuit2Minimizer::Hesse Using max-calls 3500
# Warning in <Minuit2>: MnHesse 2nd derivative zero for parameter alphaL ; MnHesse fails and will return diagonal matrix
# Warning in <Minuit2>: Minuit2Minimizer::Hesse Hesse failed - matrix is full but not positive defined
# Warning in <Minuit2>: Minuit2Minimizer::Hesse 3
# Warning in <ROOT::Math::Fitter::CalculateHessErrors>: Error when calculating Hessian

# %%
with open('../../src/parameters/uncertainty/shape_uncertainties.yaml', 'w', encoding='utf-8') as f:
    yaml.dump(uncertainties, f)

# %%
year = 'Run2'
fit_range_down, fit_range_up = 650, 4000
tagger_cut_low, tagger_cut_high = 0.9, 2

bkg_model_dir = f'output/{year}/background'

# # Background modelling
f = ROOT.TFile(f"input/{year}/data_Hbb.root", "r")
# Load TTree
tree = f.Get("Events")

# Define mass and weight variables
mass_Zprime = ROOT.RooRealVar("mass_Zprime", "mass_Zprime", 1500, fit_range_down, fit_range_up)
weight = ROOT.RooRealVar("weight", "weight", 1, -10, 10)
mass_Higgs = ROOT.RooRealVar("mass_Higgs", "mass_Higgs", 125, 0, 999)
tagger_Hbb = ROOT.RooRealVar("tagger_Hbb", "tagger_Hbb", 0, 0, 2)

SR_cut = f"(mass_Higgs>110) & (mass_Higgs<145) & (tagger_Hbb>{tagger_cut_low}) & (tagger_Hbb<{tagger_cut_high})"
sideband_cut = f"""
(
    ((mass_Higgs>50) & (mass_Higgs<70)) | 
    ((mass_Higgs>100) & (mass_Higgs<110)) | 
    (mass_Higgs>145)
) & 
(tagger_Hbb>{tagger_cut_low}) & (tagger_Hbb<{tagger_cut_high})
"""

data_SR = ROOT.RooDataSet("data_SR", "data_SR", tree, ROOT.RooArgSet(mass_Zprime, weight, mass_Higgs, tagger_Hbb), SR_cut, "weight")
data_sideband = ROOT.RooDataSet("data_sideband", "data_sideband", tree, ROOT.RooArgSet(mass_Zprime, weight, mass_Higgs, tagger_Hbb), sideband_cut, "weight")

# %%
data_sideband.sumEntries(), data_SR.sumEntries()
