# %%
import os

# %%
base = '/eos/user/d/dfu/samples/'
for m in os.listdir(base):
    filelist = []
    for f in os.listdir(os.path.join(base, m)):
        if 'NanoAOD' in f:
            filelist.append(os.path.join(base, m, f))
    with open(f'/afs/cern.ch/user/d/dfu/NanoAnalysis/condor/filelists/mc/2018/ZpToHGamma/{m}.txt', 'w', encoding='utf-8') as t:
        t.write('\n'.join(filelist))
