# %%
import awkward as ak
import uproot
import numpy as np
import os

from coffea import processor
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema

# %% [markdown]
# ## ZpToHGamma

# %%
basedir = '/data/pubfs/fudawei/mc/ZpToHGamma/'
filepath = {
    '1000GeV': '/data/pubfs/fudawei/mc/ZpToHGamma/48D5BD9C-2CF6-0C4C-8276-96AC568DDA4C.root',
}

for c in basedir:
    for (current_path, dirs, files) in os.walk(basedir[c]):
        for f in files:
            if f.endswith('.root'):
                filepath[c].append(os.path.join(current_path, f))
# Out:
# {}
