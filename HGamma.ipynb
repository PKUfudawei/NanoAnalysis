# %%
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema
import awkward as ak
import uproot
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import boost_histogram as bh
import mplhep as hep
from cycler import cycler
from src.processors.GenMatch import GenMatch
from src.processors.Processor import Processor

mpl.rcParams['axes.prop_cycle'] = cycler(color=['blue', 'darkorange', 'green', 'k',  'red',  'violet', 'darkorange', 'cyan', 'gray'])
plt.style.use(hep.style.CMS) # use CMS style for plotting

# %% [markdown]
# # Dataset

# %%
import os

filepath = '/home/pku/fudawei/production/samples/HGamma'
gen_masses = [dir for dir in os.listdir(filepath) if dir.endswith('GeV')] + ['HGamma']
samples = {gen_mass: [] for gen_mass in gen_masses}
for (current_path, dirs, files) in os.walk(top='/home/pku/fudawei/production/samples/HGamma', topdown=True):
    ## topdown=False means depth-first
    postfix = current_path.split('/')[-1]
    if postfix in gen_masses:
        samples[postfix] = os.path.join(current_path, 'total.root')
    
samples
# Out:
# {'1000GeV': '/home/pku/fudawei/production/samples/HGamma/1000GeV/total.root',
#  '1600GeV': '/home/pku/fudawei/production/samples/HGamma/1600GeV/total.root',
#  '2200GeV': '/home/pku/fudawei/production/samples/HGamma/2200GeV/total.root',
#  '2600GeV': '/home/pku/fudawei/production/samples/HGamma/2600GeV/total.root',
#  '600GeV': '/home/pku/fudawei/production/samples/HGamma/600GeV/total.root',
#  '1200GeV': '/home/pku/fudawei/production/samples/HGamma/1200GeV/total.root',
#  '800GeV': '/home/pku/fudawei/production/samples/HGamma/800GeV/total.root',
#  '900GeV': '/home/pku/fudawei/production/samples/HGamma/900GeV/total.root',
#  '3500GeV': '/home/pku/fudawei/production/samples/HGamma/3500GeV/total.root',
#  '1400GeV': '/home/pku/fudawei/production/samples/HGamma/1400GeV/total.root',
#  '3000GeV': '/home/pku/fudawei/production/samples/HGamma/3000GeV/total.root',
#  '700GeV': '/home/pku/fudawei/production/samples/HGamma/700GeV/total.root',
#  '1800GeV': '/home/pku/fudawei/production/samples/HGamma/1800GeV/total.root',
#  '2000GeV': '/home/pku/fudawei/production/samples/HGamma/2000GeV/total.root',
#  '2400GeV': '/home/pku/fudawei/production/samples/HGamma/2400GeV/total.root',
#  'HGamma': '/home/pku/fudawei/production/samples/HGamma/total.root'}

# %% [markdown]
# # From ROOT files to events

# %%
events = {
    m: NanoEventsFactory.from_root(file=samples[m], schemaclass=NanoAODSchema).events() for m in samples
}

# %% [markdown]
# ### the benefit of using nanoevents rather than awkward array

# %%
set(dir(events['HGamma'].GenPart)) - set(dir(ak.Array(events['HGamma']).GenPart))
# Out:
# set()

# %%
for gen_mass in events:
    print(gen_mass, 'events num:', len(events[gen_mass]))
# Out:
# 1000GeV events num: 50000
# 1600GeV events num: 50000
# 2200GeV events num: 50000
# 2600GeV events num: 50000
# 600GeV events num: 50000
# 1200GeV events num: 50000
# 800GeV events num: 50000
# 900GeV events num: 50000
# 3500GeV events num: 50000
# 1400GeV events num: 50000
# 3000GeV events num: 50000
# 700GeV events num: 50000
# 1800GeV events num: 50000
# 2000GeV events num: 50000
# 2400GeV events num: 50000
# HGamma events num: 750000

# %%
g = GenMatch()
s = g.HGamma(events=events['1000GeV'])

# %%
p = Processor()
a = p.process(events=events['1000GeV'])

# %%
a.keys()
# Out:
# dict_keys(['event_MET_pt', 'photon_phi', 'photon_eta', 'photon_pt', 'photon_mass', 'AK8jet_eta', 'AK8jet_pt', 'AK8jet_msoftdrop', 'AK8jet_phi', 'AK8jet_mass', "gen_Z'_eta", "gen_Z'_pt", "gen_Z'_pdgId", "gen_Z'_phi", "gen_Z'_mass", 'gen_H_eta', 'gen_H_pt', 'gen_H_pdgId', 'gen_H_phi', 'gen_H_mass', 'gen_a_eta', 'gen_a_pt', 'gen_a_pdgId', 'gen_a_phi', 'gen_a_mass', 'gen_WW_eta', 'gen_WW_pt', 'gen_WW_pdgId', 'gen_WW_phi', 'gen_WW_mass', 'gen_WW_childs_eta', 'gen_WW_childs_pt', 'gen_WW_childs_pdgId', 'gen_WW_childs_phi', 'gen_WW_childs_mass', 'gen_HWW_decay_mode'])

# %%
_events = events['1000GeV']
cutflow = [len(_events)]

# Trigger
event_cut = _events.HLT.Photon175
cutflow.append(len(_events))

# Pre-selection
## Muon
muons = _events.Muon # (event, muon)
muon_cut = ( # (event, boolean)
    # high-pT cut-based ID (1 = tracker high pT, 2 = global high pT, which includes tracker high pT)
    (muons.highPtId == 2) & 
    (muons.tkRelIso < 0.1) & # Tracker-based relative isolation dR=0.3 for highPt, trkIso/tunePpt
    (abs(muons.eta) < 2.4) & 
    (muons.pt > 20) # I don't use `muon_corrected_pt` coming from ROOT.RoccoR
)
muon = muons[muon_cut]


## Electron
electrons = _events.Electron # (event, electron)
electron_cut = ( # (event, boolean)
    (electrons.cutBased_HEEP == True) & # cut-based HEEP ID
    (abs(electrons.eta) < 2.5) &
    (electrons.pt > 20)
)
electron = electrons[electron_cut]


## Photon
photons = _events.Photon # (event, photon)
photon_cut = ( # (event, boolean)
    (photons.mvaID_WP90 > 0.2) &
    (photons.pt > 200) &
    (abs(photons.eta) < 2.4)
)
photon = photons[photon_cut]


## AK8 jet
AK8jets = _events.FatJet # (event, fatjet)
AK8jet_cut = ( # (event, boolean)
    (AK8jets.msoftdrop > 30) & # Corrected soft drop mass with PUPPI
    (AK8jets.pt > 250) & 
    (abs(AK8jets.eta) < 2.6) & 
    (AK8jets.jetId&2 > 0)
    # Jet ID flags bit1 is loose (always false in 2017 since it does not exist), bit2 is tight, bit3 is tightLepVeto
)
AK8jet = AK8jets[AK8jet_cut]

# %%
ak.num(AK8jet)
# Out:
# <Array [1, 1, 0, 0, 0, 1, ... 1, 0, 1, 1, 1, 1] type='50000 * int64'>

# %%
photon_jet_pair = ak.cartesian({'photon': photon, 'jet': AK8jet}, axis=1, nested=False)
photon_jet_pair_index = ak.argcartesian({'photon': photon, 'jet': AK8jet}, axis=1, nested=False)

photon_jet_dr = photon_jet_pair.photon.delta_r(photon_jet_pair.jet)
photon_jet_clean = (photon_jet_dr > 0.8)

photon_index, jet_index = photon_jet_pair_index.photon[photon_jet_clean], photon_jet_pair_index.jet[photon_jet_clean]

# %%
photon_index[ak.num(photon_index, axis=1)>1]
# Out:
# <Array [[0, 1], [0, 0], ... [0, 0], [0, 1]] type='321 * var * int64'>

# %%
event_cut = event_cut * (ak.sum(photon_jet_clean, axis=-1)==1)

# %%
photon_jet_pair_index.photon[photon_jet_clean]
# Out:
# <Array [[0], [0], [], [], ... [0], [0], [0]] type='50000 * var * int64'>

# %%
ak.num(photon_jet_dr)
# Out:
# <Array [1, 1, 0, 0, 0, 0, ... 1, 0, 1, 1, 1, 1] type='50000 * int64'>

# %%
photon_jet_pair_index
# Out:
# <Array [[{photon: 0, jet: 0}, ... jet: 0}]] type='50000 * var * {"photon": int64...'>

# %% [markdown]
# # Construct NanoAnalysis processor with pre-selection and gen-matching

# %%
import awkward as ak
from coffea import processor
from coffea.nanoevents.methods import candidate

class HGammaProcessor(processor.ProcessorABC):
    def __init__(self):
        pass
    
    def __preSelect(self, _events):
        cutflow = [len(_events)]

        # Trigger
        _events = _events[_events.HLT.Photon175]
        cutflow.append(len(_events))

        # Pre-selection
        ## Muon
        muons = _events.Muon # (event, muon)
        muon_cut = ( # (event, boolean)
            # high-pT cut-based ID (1 = tracker high pT, 2 = global high pT, which includes tracker high pT)
            (muons.highPtId == 2) & 
            (muons.tkRelIso < 0.1) & # Tracker-based relative isolation dR=0.3 for highPt, trkIso/tunePpt
            (abs(muons.eta) < 2.4) & 
            (muons.pt > 20) # I don't use `muon_corrected_pt` coming from ROOT.RoccoR
        )
        _events = _events[ak.sum(muon_cut, axis=1)==0] # No muon in pre-selected events
        cutflow.append(len(_events))

        ## Electron
        electrons = _events.Electron # (event, electron)
        electron_cut = ( # (event, boolean)
            (electrons.cutBased_HEEP == True) & # cut-based HEEP ID
            (abs(electrons.eta) < 2.5) &
            (electrons.pt > 20)
        )

        _events = _events[ak.sum(electron_cut, axis=1)==0] # No electron in pre-selected events
        cutflow.append(len(_events))

        ## Photon
        photons = _events.Photon # (event, photon)
        photon_cut = ( # (event, boolean)
            (photons.mvaID_WP90 > 0.2) &
            (photons.pt > 200) &
            (abs(photons.eta) < 2.4)
        )
        _events = _events[ak.sum(photon_cut, axis=1)==1] # Exactly 1 photon in pre-selected events
        cutflow.append(len(_events))

        ## AK8 jet
        AK8jets = _events.FatJet # (event, fatjet)
        AK8jet_cut = ( # (event, boolean)
            (AK8jets.msoftdrop > 30) & # Corrected soft drop mass with PUPPI
            (AK8jets.pt > 250) & 
            (abs(AK8jets.eta) < 2.6) & 
            (AK8jets.jetId&2 > 0)
            # Jet ID flags bit1 is loose (always false in 2017 since it does not exist), bit2 is tight, bit3 is tightLepVeto
        )
        _events = _events[ak.sum(AK8jet_cut, axis=1)==1] # Exactly 1 AK8 jet in pre-selected events
        cutflow.append(len(_events))

        # Drop unselected photon and AK8 jet in events (Have to do again cuz FatJet cut not inherited)
        photons = _events.Photon # (event, photon)
        photon_cut = ( # (event, boolean)
            (photons.mvaID_WP90 > 0.2) &
            (photons.pt > 200) &
            (abs(photons.eta) < 2.4)
        )
        _events.Photon = _events.Photon[photon_cut]

        AK8jets = _events.FatJet # (event, fatjet)
        AK8jet_cut = ( # (event, boolean)
            (AK8jets.msoftdrop > 30) & # Corrected soft drop mass with PUPPI
            (AK8jets.pt > 250) & 
            (abs(AK8jets.eta) < 2.6) & 
            (AK8jets.jetId&2 > 0)
            # Jet ID flags bit1 is loose (always false in 2017 since it does not exist), bit2 is tight, bit3 is tightLepVeto
        )
        _events.FatJet = _events.FatJet[AK8jet_cut]

        ## Photon-Jet cleaning
        jet_cleaning = (_events.FatJet.delta_r(_events.Photon) > 0.8)
        _events = _events[ak.sum(jet_cleaning, axis=1)>0]
        cutflow.append(len(_events))
        
        return _events, cutflow
            
    def __genMatching(self, _events):
        "statusFlags().isLastCopyBeforeFSR()                  * 16384 +"
        "statusFlags().isLastCopy()                           * 8192  +"
        "statusFlags().isFirstCopy()                          * 4096  +"
        "statusFlags().fromHardProcessBeforeFSR()             * 2048  +"
        "statusFlags().isDirectHardProcessTauDecayProduct()   * 1024  +"
        "statusFlags().isHardProcessTauDecayProduct()         * 512   +"
        "statusFlags().fromHardProcess()                      * 256   +"
        "statusFlags().isHardProcess()                        * 128   +"
        "statusFlags().isDirectHadronDecayProduct()           * 64    +"
        "statusFlags().isDirectPromptTauDecayProduct()        * 32    +"
        "statusFlags().isDirectTauDecayProduct()              * 16    +"
        "statusFlags().isPromptTauDecayProduct()              * 8     +"
        "statusFlags().isTauDecayProduct()                    * 4     +"
        "statusFlags().isDecayedLeptonHadron()                * 2     +"
        "statusFlags().isPrompt()                             * 1      "
        gen_Higgs = _events.GenPart[ # (event, particle)
            (_events.GenPart.pdgId == 25) & # select all Higgs
            (_events.GenPart.hasFlags(['isLastCopy'])) # Higgs is the last copy
        ] # (event, Higgs)

        gen_gamma = _events.GenPart[ # (event, particle)
            (_events.GenPart.pdgId == 22) & # select all gamma
            (_events.GenPart.hasFlags(['isLastCopy'])) # gamma is the last copy
        ] # (event, gamma)
        
        gen_H_children = gen_Higgs.children
        gen_HWW = gen_H_children[ # (event, Higgs, W)
            (ak.num(gen_H_children, axis=2) == 2) & # Higgs has two children
            ak.all(np.abs(gen_H_children.pdgId) == 24, axis=2) # both childen are W 
        ] # (event, Higgs, W)

        gen_HWW_children = gen_HWW.children
        gen_HWW_children = gen_HWW_children[
            ak.all(ak.num(gen_HWW_children, axis=3) == 2, axis=2) # both W has two children
        ] # (event, Higgs, W, W_child)

        gen_HWW_Wtag = ( # (event, Higgs, W)
            ak.zeros_like(ak.any(gen_HWW_children.pdgId, axis=3)) +
            1 * ak.any(abs(gen_HWW_children.pdgId)==11, axis=3) + # one W decays to e
            2 * ak.any(abs(gen_HWW_children.pdgId)==13, axis=3) + # one W decays to mu
            4 * ak.any(abs(gen_HWW_children.pdgId)==15, axis=3) + # one W decays to tau
            8 * ak.all(abs(gen_HWW_children.pdgId)<7, axis=3)   # one W decays to qq
        ) # (event, Higgs, W)
        gen_HWW_Wtag = gen_HWW_Wtag[ak.sum(gen_HWW_Wtag, axis=2, keepdims=False)>8] # at least one W-->qq
        gen_HWW_tag = ak.sum(gen_HWW_Wtag, axis=2) # (event, Higgs)
        
        cut = (
            (ak.num(gen_gamma, axis=1)>0) &
            (ak.num(gen_HWW_tag, axis=1)>0)
        )
        
        gen_HGamma_events = _events[cut] # (event, )
        
        return gen_HGamma_events, gen_HWW_tag
    
    def process(self, events):
        preselected_events, cutflow = self.__preSelect(events)
        gen_HGamma_events, gen_HWW_tag = self.__genMatching(events)
        return preselected_events, cutflow, gen_HGamma_events, gen_HWW_tag

    def postprocess(self, accumulator):
        pass

# %% [markdown]
# # Start running

# %%
events
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/pku/fudawei/GitRepo/NanoAnalysis/HGamma.ipynb Cell 22 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bfarm/home/pku/fudawei/GitRepo/NanoAnalysis/HGamma.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> events
#
# File ~/anaconda3/lib/python3.8/site-packages/IPython/core/displayhook.py:262, in DisplayHook.__call__(self, result)
#     260 self.start_displayhook()
#     261 self.write_output_prompt()
# --> 262 format_dict, md_dict = self.compute_format_data(result)
#     263 self.update_user_ns(result)
#     264 self.fill_exec_result(result)
#
# File ~/anaconda3/lib/python3.8/site-packages/IPython/core/displayhook.py:151, in DisplayHook.compute_format_data(self, result)
#     121 def compute_format_data(self, result):
#     122     """Compute format data of the object to be displayed.
#     123
#     124     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     149
#     150     """
# --> 151     return self.shell.display_formatter.format(result)
#
# File ~/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File ~/anaconda3/lib/python3.8/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     702     self.max_width, self.newline,
#     703     max_seq_length=self.max_seq_length,
#     704     singleton_pprinters=self.singleton_printers,
#     705     type_pprinters=self.type_printers,
#     706     deferred_pprinters=self.deferred_printers)
# --> 707 printer.pretty(obj)
#     708 printer.flush()
#     709 return stream.getvalue()
#
# File ~/anaconda3/lib/python3.8/site-packages/IPython/lib/pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~/anaconda3/lib/python3.8/site-packages/IPython/lib/pretty.py:692, in _dict_pprinter_factory.<locals>.inner(obj, p, cycle)
#     690     p.pretty(key)
#     691     p.text(': ')
# --> 692     p.pretty(obj[key])
#     693 p.end_group(step, end)
#
# File ~/anaconda3/lib/python3.8/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~/anaconda3/lib/python3.8/site-packages/IPython/lib/pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~/.local/lib/python3.8/site-packages/awkward/highlevel.py:1302, in Array.__repr__(self)
#    1287 def __repr__(self):
#    1288     """
#    1289     Args:
#    1290         limit_value (int): Maximum number of characters to use when
#    (...)
#    1300     of its string (the outermost data structures).
#    1301     """
# -> 1302     return self._repr()
#
# File ~/.local/lib/python3.8/site-packages/awkward/highlevel.py:1313, in Array._repr(self, limit_value, limit_total)
#    1310 suffix = _suffix(self)
#    1311 limit_value -= len(suffix)
# -> 1313 value = ak._util.minimally_touching_string(
#    1314     limit_value, self.layout, self._behavior
#    1315 )
#    1317 try:
#    1318     name = super(Array, self).__getattribute__("__name__")
#
# File ~/.local/lib/python3.8/site-packages/awkward/_util.py:1663, in minimally_touching_string(limit_length, layout, behavior)
#    1659 rightgen = forever(
#    1660     backward(layout, "", brackets=False, wrap=False, stop=halfway - 1)
#    1661 )
#    1662 while True:
# -> 1663     lft = next(leftgen)
#    1664     rgt = next(rightgen)
#    1666     if lft is not None:
#
# File ~/.local/lib/python3.8/site-packages/awkward/_util.py:1650, in minimally_touching_string.<locals>.forever(iterable)
#    1649 def forever(iterable):
# -> 1650     for token in iterable:
#    1651         yield token
#    1652     while True:
#
# File ~/.local/lib/python3.8/site-packages/awkward/_util.py:1544, in minimally_touching_string.<locals>.forward(x, space, brackets, wrap, stop)
#    1542 sp = ""
#    1543 for i in range(len(x) if stop is None else stop):
# -> 1544     for token in forward(x[i], sp):
#    1545         yield token
#    1546     sp = ", "
#
# File ~/.local/lib/python3.8/site-packages/awkward/_util.py:1536, in minimally_touching_string.<locals>.forward(x, space, brackets, wrap, stop)
#    1534         y = cls(x, behavior=behavior)
#    1535         if "__repr__" in type(y).__dict__:
# -> 1536             yield space + repr(y)
#    1537             done = True
#    1538 if not done:
#
# File ~/.local/lib/python3.8/site-packages/coffea/nanoevents/methods/nanoaod.py:14, in _NanoAODEvents.__repr__(self)
#      13 def __repr__(self):
# ---> 14     return f"<event {self.run}:{self.luminosityBlock}:{self.event}>"
#
# File ~/.local/lib/python3.8/site-packages/awkward/highlevel.py:1836, in Record.__getattr__(self, where)
#    1834 if where in self.layout.keys():
#    1835     try:
# -> 1836         return self[where]
#    1837     except Exception as err:
#    1838         raise AttributeError(
#    1839             "while trying to get field {0}, an exception "
#    1840             "occurred:\n{1}: {2}".format(repr(where), type(err), str(err))
#    1841             + ak._util.exception_suffix(__file__)
#    1842         )
#
# File ~/.local/lib/python3.8/site-packages/awkward/highlevel.py:1763, in Record.__getitem__(self, where)
#    1737 def __getitem__(self, where):
#    1738     """
#    1739     Args:
#    1740         where (many types supported; see below): Index of positions to
#    (...)
#    1761         2
#    1762     """
# -> 1763     tmp = ak._util.wrap(self.layout[where], self._behavior)
#    1765     if isinstance(tmp, ak.behaviors.string.ByteBehavior):
#    1766         return bytes(tmp)
#
# File ~/.local/lib/python3.8/site-packages/awkward/operations/convert.py:4705, in _form_to_layout(form, container, partnum, key_format, length, lazy_cache, lazy_cache_key)
#    4699     return _form_to_layout_class[type(form), form.offsets](
#    4700         offsets, content, identities, parameters
#    4701     )
#    4703 elif isinstance(form, ak.forms.NumpyForm):
#    4704     raw_array = _asbuf(
# -> 4705         container[key_format(form_key=fk, attribute="data", partition=partnum)]
#    4706     )
#    4707     dtype_inner_shape = form.to_numpy()
#    4708     if dtype_inner_shape.subdtype is None:
#
# File ~/.local/lib/python3.8/site-packages/coffea/nanoevents/mapping/base.py:90, in BaseSourceMapping.__getitem__(self, key)
#      86         self._access_log.append(handle_name)
#      87     handle = self.get_column_handle(
#      88         self._column_source(uuid, treepath), handle_name
#      89     )
# ---> 90     stack.append(self.extract_column(handle, start, stop))
#      91 elif node.startswith("!"):
#      92     tname = node[1:]
#
# File ~/.local/lib/python3.8/site-packages/coffea/nanoevents/mapping/uproot.py:115, in UprootSourceMapping.extract_column(self, columnhandle, start, stop)
#     113 def extract_column(self, columnhandle, start, stop):
#     114     # make sure uproot is single-core since our calling context might not be
# --> 115     return columnhandle.array(
#     116         entry_start=start,
#     117         entry_stop=stop,
#     118         decompression_executor=uproot.source.futures.TrivialExecutor(),
#     119         interpretation_executor=uproot.source.futures.TrivialExecutor(),
#     120     )
#
# File ~/.local/lib/python3.8/site-packages/uproot/behaviors/TBranch.py:2079, in TBranch.array(self, interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library)
#    2073             for (
#    2074                 basket_num,
#    2075                 range_or_basket,
#    2076             ) in branch.entries_to_ranges_or_baskets(entry_start, entry_stop):
#    2077                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
# -> 2079 _ranges_or_baskets_to_arrays(
#    2080     self,
#    2081     ranges_or_baskets,
#    2082     branchid_interpretation,
#    2083     entry_start,
#    2084     entry_stop,
#    2085     decompression_executor,
#    2086     interpretation_executor,
#    2087     library,
#    2088     arrays,
#    2089     False,
#    2090 )
#    2092 _fix_asgrouped(
#    2093     arrays, expression_context, branchid_interpretation, library, None
#    2094 )
#    2096 if array_cache is not None:
#
# File ~/.local/lib/python3.8/site-packages/uproot/behaviors/TBranch.py:3391, in _ranges_or_baskets_to_arrays(hasbranches, ranges_or_baskets, branchid_interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, library, arrays, update_ranges_or_baskets)
#    3386         if cache_key not in arrays:
#    3387             arrays[cache_key] = interpretation.final_array(
#    3388                 {}, 0, 0, [0], library, None
#    3389             )
# -> 3391 hasbranches._file.source.chunks(ranges, notifications=notifications)
#    3393 def replace(ranges_or_baskets, original_index, basket):
#    3394     branch, basket_num, range_or_basket = ranges_or_baskets[original_index]
#
# File ~/.local/lib/python3.8/site-packages/uproot/source/file.py:170, in MemmapSource.chunks(self, ranges, notifications)
#     168 chunks = []
#     169 for start, stop in ranges:
# --> 170     data = numpy.array(self._file[start:stop], copy=True)
#     171     future = uproot.source.futures.TrivialFuture(data)
#     172     chunk = uproot.source.chunk.Chunk(self, start, stop, future)
#
# KeyboardInterrupt:

# %%
p = HGammaProcessor()
preselected_events = {m: None for m in events}
cutflow = {m: None for m in events}
gen_HGamma_events = {m: None for m in events}
gen_HWW_tag = {m: None for m in events}

for m in events:
    preselected_events[m], cutflow[m], gen_HGamma_events[m], gen_HWW_tag = p.process(events[m])
preselected_events, gen_HGamma_events
# Out:
# ({'1000GeV': <NanoEventsArray [<event 1:1:6>, ... <event 1:48:48000>] type='21605 * event'>,
#   '1600GeV': <NanoEventsArray [<event 1:1:9>, ... <event 1:50:49994>] type='27834 * event'>,
#   '2200GeV': <NanoEventsArray [<event 1:1:8>, ... <event 1:50:49999>] type='29596 * event'>,
#   '2600GeV': <NanoEventsArray [<event 1:1:8>, ... <event 1:36:36000>] type='29879 * event'>,
#   '600GeV': <NanoEventsArray [<event 1:49:48023>, ... ] type='4121 * event'>,
#   '1200GeV': <NanoEventsArray [<event 1:7:6006>, ... ] type='24805 * event'>,
#   '800GeV': <NanoEventsArray [<event 1:1:20>, ... <event 1:50:49994>] type='15653 * event'>,
#   '900GeV': <NanoEventsArray [<event 1:25:24001>, ... ] type='19012 * event'>,
#   '3500GeV': <NanoEventsArray [<event 1:46:45008>, ... ] type='29873 * event'>,
#   '1400GeV': <NanoEventsArray [<event 1:1:7>, ... <event 1:50:49987>] type='26755 * event'>,
#   '3000GeV': <NanoEventsArray [<event 1:43:42006>, ... ] type='30079 * event'>,
#   '700GeV': <NanoEventsArray [<event 1:5:4005>, ... ] type='10622 * event'>,
#   '1800GeV': <NanoEventsArray [<event 1:21:20006>, ... ] type='28678 * event'>,
#   '2000GeV': <NanoEventsArray [<event 1:11:10006>, ... ] type='29517 * event'>,
#   '2400GeV': <NanoEventsArray [<event 1:1:7>, ... <event 1:48:47997>] type='29534 * event'>,
#   'HGamma': <NanoEventsArray [<event 1:1:6>, ... <event 1:48:47995>] type='357563 * event'>},
#  {'1000GeV': <NanoEventsArray [<event 1:1:6>, ... <event 1:48:47993>] type='8677 * event'>,
#   '1600GeV': <NanoEventsArray [<event 1:1:9>, ... <event 1:50:49999>] type='8617 * event'>,
#   '2200GeV': <NanoEventsArray [<event 1:1:9>, ... <event 1:50:49987>] type='8541 * event'>,
#   '2600GeV': <NanoEventsArray [<event 1:1:8>, ... <event 1:36:35991>] type='8600 * event'>,
#   '600GeV': <NanoEventsArray [<event 1:49:48008>, ... ] type='8792 * event'>,
#   '1200GeV': <NanoEventsArray [<event 1:7:6001>, ... ] type='8452 * event'>,
#   '800GeV': <NanoEventsArray [<event 1:1:9>, ... <event 1:50:49994>] type='8534 * event'>,
#   '900GeV': <NanoEventsArray [<event 1:25:24028>, ... ] type='8533 * event'>,
#   '3500GeV': <NanoEventsArray [<event 1:46:45012>, ... ] type='8624 * event'>,
#   '1400GeV': <NanoEventsArray [<event 1:1:1>, ... <event 1:50:49990>] type='8616 * event'>,
#   '3000GeV': <NanoEventsArray [<event 1:43:42007>, ... ] type='8523 * event'>,
#   '700GeV': <NanoEventsArray [<event 1:5:4014>, ... ] type='8568 * event'>,
#   '1800GeV': <NanoEventsArray [<event 1:21:20006>, ... ] type='8535 * event'>,
#   '2000GeV': <NanoEventsArray [<event 1:11:10006>, ... ] type='8700 * event'>,
#   '2400GeV': <NanoEventsArray [<event 1:1:1>, ... <event 1:48:47999>] type='8572 * event'>,
#   'HGamma': <NanoEventsArray [<event 1:1:6>, ... <event 1:48:48000>] type='128884 * event'>})

# %% [markdown]
# # Store output
# ### It takes long time, be patient

# %%
ak.to_parquet(array=preselected_events['HGamma'], where='./output/preselected_events.parq')
ak.to_parquet(array=gen_HGamma_events['HGamma'], where='./output/gen_HGamma_events.parq')
# Out:
# /home/olympus/fudawei/anaconda3/lib/python3.9/site-packages/awkward/operations/convert.py:1999: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if distutils.version.LooseVersion(
# /home/olympus/fudawei/anaconda3/lib/python3.9/site-packages/awkward/operations/convert.py:2001: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   ) < distutils.version.LooseVersion("2.0.0"):
# /home/olympus/fudawei/anaconda3/lib/python3.9/site-packages/awkward/_connect/_numba/__init__.py:30: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not checked_version and distutils.version.LooseVersion(
# /home/olympus/fudawei/anaconda3/lib/python3.9/site-packages/awkward/_connect/_numba/__init__.py:32: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   ) < distutils.version.LooseVersion("0.50"):
# /home/olympus/fudawei/anaconda3/lib/python3.9/site-packages/awkward/operations/convert.py:1999: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if distutils.version.LooseVersion(
# /home/olympus/fudawei/anaconda3/lib/python3.9/site-packages/awkward/operations/convert.py:2001: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   ) < distutils.version.LooseVersion("2.0.0"):

# %%
def plot(labels, filename, distributions, bins=10, x_min=0, x_max=10, density=False, stack=False, colorlist=['red', 'blue', 'green', 'black', 'cyan', 'darkorange', 'darkviolet', 'SlateGray', 'HotPink', 'LightSkyBlue']):
    ## canvas initializing
    mpl.rcParams['axes.prop_cycle'] = cycler(color=colorlist)
    #f, ax = plt.subplots()
    plt.figure(figsize=(8,8))
    ax=plt.gca()
    plt.grid()
    hep.cms.label(data=False, year=2018, ax=ax)
    
    
    ## plot
    for i in range(len(labels)):
        hist = bh.Histogram(bh.axis.Regular(bins, x_min, x_max), storage=bh.storage.Weight())
        var = distributions[i]
        hist.fill(var)
        h, err = hist.view().value, np.sqrt(hist.view().variance)
        hep.histplot(h, bins=hist.axes[0].edges, yerr=err, label=labels[i], histtype='step', density=density, stack=stack)


    ## axises
    plt.xlim(x_min, x_max)
    plt.ylim(0, ax.get_ylim()[1]*1.1)
    ax.ticklabel_format(useOffset=False, style='plain')
    #x_major_locator=plt.MultipleLocator(bin_width*8 if variable=='fj_gen_mass' else bin_width*2)
    #y_major_locator=MultipleLocator(1)
    #ax.xaxis.set_major_locator(x_major_locator)
    #ax.yaxis.set_major_locator(y_major_locator)
    if density==False:
        plt.ylabel('Events', fontsize=20, ha='right', y=1)
    elif density==True:    
        plt.ylabel('A.U.', fontsize=20, ha='right', y=1)
    plt.xlabel(r'$N_{AK8}$', fontsize=20, ha='right', x=1)

    plt.xticks(size=14)
    plt.yticks(size=14)


    ## title, text and legend
    #plt.title('ROC Curve of HWW4q vs. QCD', fontsize=24,color="black")
    plt.legend(loc="best", ncol=1, frameon=False,fontsize=18)
    #plt.text(0.96*ax.get_xlim()[1], ax.get_ylim()[1]*0.72,"At "+r"$\mathrm{m^{gen}_{H}=}$"+f"{Higgsmass} GeV", fontsize=24, color="black", ha='right')


    ## finalizing
    suffix=''
    if density==True:   suffix+='_AU'
    if stack==True:     suffix+='_stack'
    plt.savefig("plots/"+filename+suffix+".pdf", bbox_inches='tight')
    plt.show()
