# %%
for ht in [[50, 100], [100, 200], [200, 300], [300, 500], [500, 700], [700, 1000], [1000, 1500], [1500, 2000], [2000, 'Inf']]:
    print(f"QCD_HT{ht[0]}to{ht[1]}_TuneCP5:\n    dataset: /QCD_HT{ht[0]}to{ht[1]}_TuneCP5_13TeV-madgraphMLM-pythia8/RunIIAutumn18NanoAODv7-Nano02Apr2020_102X_upgrade2018_realistic_v21-v1/NANOAODSIM")
# Out:
# QCD_HT50to100_TuneCP5:
#     dataset: /QCD_HT50to100_TuneCP5_13TeV-madgraphMLM-pythia8/RunIIAutumn18NanoAODv7-Nano02Apr2020_102X_upgrade2018_realistic_v21-v1/NANOAODSIM
# QCD_HT100to200_TuneCP5:
#     dataset: /QCD_HT100to200_TuneCP5_13TeV-madgraphMLM-pythia8/RunIIAutumn18NanoAODv7-Nano02Apr2020_102X_upgrade2018_realistic_v21-v1/NANOAODSIM
# QCD_HT200to300_TuneCP5:
#     dataset: /QCD_HT200to300_TuneCP5_13TeV-madgraphMLM-pythia8/RunIIAutumn18NanoAODv7-Nano02Apr2020_102X_upgrade2018_realistic_v21-v1/NANOAODSIM
# QCD_HT300to500_TuneCP5:
#     dataset: /QCD_HT300to500_TuneCP5_13TeV-madgraphMLM-pythia8/RunIIAutumn18NanoAODv7-Nano02Apr2020_102X_upgrade2018_realistic_v21-v1/NANOAODSIM
# QCD_HT500to700_TuneCP5:
#     dataset: /QCD_HT500to700_TuneCP5_13TeV-madgraphMLM-pythia8/RunIIAutumn18NanoAODv7-Nano02Apr2020_102X_upgrade2018_realistic_v21-v1/NANOAODSIM
# QCD_HT700to1000_TuneCP5:
# ...
