# %%
ht = [40, 100, 200, 400, 600, 'Inf']
for i in range(len(ht)-1):
    print(f"GJets_HT-{ht[i]}To{ht[i+1]}_TuneCP5:\n    dataset: /GJets_HT-{ht[i]}To{ht[i+1]}_TuneCP5_13TeV-madgraphMLM-pythia8/RunIIFall17NanoAODv7-PU2017_12Apr2018_Nano02Apr2020_102X_mc2017_realistic_v8-v1/NANOAODSIM")
# Out:
# GJets_HT-40To100_TuneCP5:
#     dataset: /GJets_HT-40To100_TuneCP5_13TeV-madgraphMLM-pythia8/RunIIFall17NanoAODv7-PU2017_12Apr2018_Nano02Apr2020_102X_mc2017_realistic_v8-v1/NANOAODSIM
# GJets_HT-100To200_TuneCP5:
#     dataset: /GJets_HT-100To200_TuneCP5_13TeV-madgraphMLM-pythia8/RunIIFall17NanoAODv7-PU2017_12Apr2018_Nano02Apr2020_102X_mc2017_realistic_v8-v1/NANOAODSIM
# GJets_HT-200To400_TuneCP5:
#     dataset: /GJets_HT-200To400_TuneCP5_13TeV-madgraphMLM-pythia8/RunIIFall17NanoAODv7-PU2017_12Apr2018_Nano02Apr2020_102X_mc2017_realistic_v8-v1/NANOAODSIM
# GJets_HT-400To600_TuneCP5:
#     dataset: /GJets_HT-400To600_TuneCP5_13TeV-madgraphMLM-pythia8/RunIIFall17NanoAODv7-PU2017_12Apr2018_Nano02Apr2020_102X_mc2017_realistic_v8-v1/NANOAODSIM
# GJets_HT-600ToInf_TuneCP5:
#     dataset: /GJets_HT-600ToInf_TuneCP5_13TeV-madgraphMLM-pythia8/RunIIFall17NanoAODv7-PU2017_12Apr2018_Nano02Apr2020_102X_mc2017_realistic_v8-v1/NANOAODSIM
